# %% [markdown]
# # What's the Weather Like?
#
# ## Observed Data Trend 1:
#
# The clearest trend shown in the four below plots is for Latitude vs. Max Temp. The data shows a nice bell curve centered near the 20 degree N latitude. It would be interesting to track this over a year to see how this changes for the different seasons.
#
# ## Observed Data Trend 2:
#
# For the relation Latitude vs. Humidity, one interesting note is that a majority of the cities have a humidity of above 60% and almost all of the cities are at least at the 20% humidity mark. I would be interested in tracking this relationship of humidty vs. distane of city from nearest ocean to see if there is any obvious trend here.
#
# ## Observed Data Trend 3:
#
# A point of interest for the Latitude vs. Cloudiness plot is that there are clear groups of observations on the factors of 20% lines. However, there seems to be an exception at 60% and 80% where this group is actually on the 75% line. I assume that "cloudiness" reports are typically rounded to nice even values which is why we observe these groupings. Why many reports use the 75% rounded value instead of 60% or 80% whereas the other rounded reports are all factors of 20% is a bit odd. Maybe I am making the wrong assumption and the measure of cloudiness is very scientific and it just so happens that we rarely see 60% or 80% recordings but I am skeptical of this. I would further research the common practice for "cloudiness" reports to see what is really going on with the data here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from datetime import date

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 599

# %%
# storing city names in first column of dataframe
df = pd.DataFrame(cities)
df = df.rename(columns = {0: "City"})

# %%
# creating column names
df['Cloudiness'] = ""
df['Country'] = ""
df['Date'] = ""
df['Humidity'] = ""
df['Lat'] = ""
df['Lng'] = ""
df['Max Temp'] = ""
df['Wind Speed'] = ""
df.head()
# Out:
#           City Cloudiness Country Date Humidity Lat Lng Max Temp Wind Speed
# 0  baie-comeau
# 1        tokur
# 2      sechura
# 3    hithadhoo
# 4      rikitea

# %%
# setting url and units parameter
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# %%
# using my api_key
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
# checking out the json file for a specific city to see keys
response = requests.get(query_url +"London").json()
response
# Out:
# {'coord': {'lon': -0.13, 'lat': 51.51},
#  'weather': [{'id': 521,
#    'main': 'Rain',
#    'description': 'shower rain',
#    'icon': '09d'}],
#  'base': 'stations',
#  'main': {'temp': 69.33,
#   'pressure': 1018,
#   'humidity': 64,
#   'temp_min': 63,
#   'temp_max': 73.4},
#  'visibility': 10000,
#  'wind': {'speed': 5.82, 'deg': 180},
#  'clouds': {'all': 100},
#  'dt': 1561405412,
#  'sys': {'type': 1,
#   'id': 1414,
#   'message': 0.0101,
#   'country': 'GB',
#   'sunrise': 1561347827,
#   'sunset': 1561407709},
#  'timezone': 3600,
#  'id': 2643743,
#  'name': 'London',
#  'cod': 200}

# %%
# data retreival process

print("Beginning Data Retrieval \n ---------------------")

for index, row in df.iterrows():
    
    city_name = row["City"]

    # assemble url and make API request
    print(f"Processing Record for Index {index}: {city_name}")
    response = requests.get(query_url + city_name).json()
    
    #storing each value from json to dataframe city by city, if keyerror or indexerror skip and print message
    try: 
        df.loc[index, 'Cloudiness'] = response['clouds']['all']
        df.loc[index, 'Country'] = response['sys']['country']
        df.loc[index, 'Date'] = response['dt']
        df.loc[index, 'Humidity'] = response['main']['humidity']
        df.loc[index, 'Lat'] = response['coord']['lat']
        df.loc[index, 'Lng'] = response['coord']['lon']
        df.loc[index, 'Max Temp'] = response['main']['temp_max']
        df.loc[index, 'Wind Speed'] = response['wind']['speed']
        
    except (KeyError, IndexError):
        print("City not found... skipping.")
              
              
print("--------------------- \nData Retrieval Complete. \n---------------------")
# Out:
# Beginning Data Retrieval
#  ---------------------
# Processing Record for Index 0: baie-comeau
# Processing Record for Index 1: tokur
# Processing Record for Index 2: sechura
# Processing Record for Index 3: hithadhoo
# Processing Record for Index 4: rikitea
# Processing Record for Index 5: sarh
# Processing Record for Index 6: niamey
# Processing Record for Index 7: avarua
# Processing Record for Index 8: jardim
# Processing Record for Index 9: iqaluit
# Processing Record for Index 10: victoria
# Processing Record for Index 11: vila velha
# Processing Record for Index 12: tawkar
# City not found... skipping.
# Processing Record for Index 13: ushuaia
# Processing Record for Index 14: kuusamo
# Processing Record for Index 15: busselton
# Processing Record for Index 16: arraial do cabo
# Processing Record for Index 17: shitkino
# Processing Record for Index 18: butaritari
# Processing Record for Index 19: cayenne
# Processing Record for Index 20: baikunthpur
# Processing Record for Index 21: provideniya
# Processing Record for Index 22: laiyang
# Processing Record for Index 23: kaitangata
# Processing Record for Index 24: barentsburg
# City not found... skipping.
# Processing Record for Index 25: portland
# Processing Record for Index 26: le port
# Processing Record for Index 27: isangel
# Processing Record for Index 28: mataura
# Processing Record for Index 29: bambous virieux
# Processing Record for Index 30: kristallopiyi
# City not found... skipping.
# Processing Record for Index 31: zavetnoye
# Processing Record for Index 32: aklavik
# Processing Record for Index 33: bernay
# Processing Record for Index 34: jamestown
# Processing Record for Index 35: fasa
# Processing Record for Index 36: hermanus
# Processing Record for Index 37: carnarvon
# Processing Record for Index 38: vaini
# Processing Record for Index 39: new norfolk
# Processing Record for Index 40: taolanaro
# City not found... skipping.
# Processing Record for Index 41: amderma
# City not found... skipping.
# Processing Record for Index 42: grand river south east
# City not found... skipping.
# Processing Record for Index 43: hays
# Processing Record for Index 44: fairbanks
# Processing Record for Index 45: nouakchott
# Processing Record for Index 46: roma
# Processing Record for Index 47: mahebourg
# Processing Record for Index 48: saskylakh
# Processing Record for Index 49: albany
# Processing Record for Index 50: ust-nera
# Processing Record for Index 51: komsomolskiy
# Processing Record for Index 52: high prairie
# Processing Record for Index 53: lolua
# City not found... skipping.
# Processing Record for Index 54: katsuura
# Processing Record for Index 55: constitucion
# Processing Record for Index 56: itoman
# Processing Record for Index 57: tuatapere
# Processing Record for Index 58: ponta delgada
# Processing Record for Index 59: qaanaaq
# Processing Record for Index 60: sayyan
# Processing Record for Index 61: punta arenas
# Processing Record for Index 62: fukue
# Processing Record for Index 63: kutum
# Processing Record for Index 64: corinto
# Processing Record for Index 65: port alfred
# Processing Record for Index 66: huambo
# Processing Record for Index 67: dikson
# Processing Record for Index 68: cidreira
# Processing Record for Index 69: brae
# Processing Record for Index 70: ust-omchug
# Processing Record for Index 71: iseyin
# Processing Record for Index 72: anshun
# Processing Record for Index 73: nizhneyansk
# City not found... skipping.
# Processing Record for Index 74: bredasdorp
# Processing Record for Index 75: bluff
# Processing Record for Index 76: codrington
# Processing Record for Index 77: warrnambool
# Processing Record for Index 78: barawe
# City not found... skipping.
# Processing Record for Index 79: east london
# Processing Record for Index 80: lebu
# Processing Record for Index 81: xique-xique
# Processing Record for Index 82: russell
# Processing Record for Index 83: nikolskoye
# Processing Record for Index 84: chokurdakh
# Processing Record for Index 85: vila franca do campo
# Processing Record for Index 86: faanui
# Processing Record for Index 87: mahadday weyne
# City not found... skipping.
# Processing Record for Index 88: ancud
# Processing Record for Index 89: barrow
# Processing Record for Index 90: filotion
# Processing Record for Index 91: castro
# Processing Record for Index 92: atuona
# Processing Record for Index 93: tomislavgrad
# Processing Record for Index 94: bondo
# Processing Record for Index 95: atka
# City not found... skipping.
# Processing Record for Index 96: clyde river
# Processing Record for Index 97: teknaf
# Processing Record for Index 98: coquimbo
# Processing Record for Index 99: tsihombe
# City not found... skipping.
# Processing Record for Index 100: belushya guba
# City not found... skipping.
# Processing Record for Index 101: sakakah
# City not found... skipping.
# Processing Record for Index 102: yulara
# Processing Record for Index 103: ikalamavony
# Processing Record for Index 104: yellowknife
# Processing Record for Index 105: tyrma
# Processing Record for Index 106: hobart
# Processing Record for Index 107: lorengau
# Processing Record for Index 108: georgetown
# Processing Record for Index 109: kodiak
# Processing Record for Index 110: okhotsk
# Processing Record for Index 111: tiksi
# Processing Record for Index 112: anicuns
# Processing Record for Index 113: verkhnevilyuysk
# Processing Record for Index 114: sao filipe
# Processing Record for Index 115: vaitupu
# City not found... skipping.
# Processing Record for Index 116: lucea
# Processing Record for Index 117: barcelos
# Processing Record for Index 118: surt
# Processing Record for Index 119: sinop
# Processing Record for Index 120: anadyr
# Processing Record for Index 121: esperance
# Processing Record for Index 122: sorvag
# City not found... skipping.
# Processing Record for Index 123: norman wells
# Processing Record for Index 124: kolobrzeg
# Processing Record for Index 125: arraias
# Processing Record for Index 126: grand centre
# City not found... skipping.
# Processing Record for Index 127: magaria
# Processing Record for Index 128: villa maria
# Processing Record for Index 129: phan rang
# City not found... skipping.
# Processing Record for Index 130: cape town
# Processing Record for Index 131: nouadhibou
# Processing Record for Index 132: upernavik
# Processing Record for Index 133: chuy
# Processing Record for Index 134: cabo san lucas
# Processing Record for Index 135: tasiilaq
# Processing Record for Index 136: vicosa
# Processing Record for Index 137: tazovskiy
# Processing Record for Index 138: zhanaozen
# Processing Record for Index 139: saint-philippe
# Processing Record for Index 140: alvaraes
# Processing Record for Index 141: pacific grove
# Processing Record for Index 142: saleaula
# City not found... skipping.
# Processing Record for Index 143: illoqqortoormiut
# City not found... skipping.
# Processing Record for Index 144: ngunguru
# Processing Record for Index 145: harper
# Processing Record for Index 146: bethel
# Processing Record for Index 147: cherskiy
# Processing Record for Index 148: geraldton
# Processing Record for Index 149: rydultowy
# Processing Record for Index 150: sentyabrskiy
# City not found... skipping.
# Processing Record for Index 151: hami
# Processing Record for Index 152: tabas
# Processing Record for Index 153: dingle
# Processing Record for Index 154: lompoc
# Processing Record for Index 155: alyangula
# Processing Record for Index 156: hofn
# Processing Record for Index 157: kearney
# Processing Record for Index 158: ribeira grande
# Processing Record for Index 159: road town
# Processing Record for Index 160: shu
# Processing Record for Index 161: ahipara
# Processing Record for Index 162: la ronge
# Processing Record for Index 163: zamora
# Processing Record for Index 164: sisimiut
# Processing Record for Index 165: tuktoyaktuk
# Processing Record for Index 166: kenai
# Processing Record for Index 167: ibirama
# Processing Record for Index 168: kamenka
# Processing Record for Index 169: nome
# Processing Record for Index 170: patnos
# Processing Record for Index 171: palmer
# Processing Record for Index 172: gillette
# Processing Record for Index 173: churapcha
# Processing Record for Index 174: bandundu
# Processing Record for Index 175: umm lajj
# Processing Record for Index 176: touros
# Processing Record for Index 177: sorong
# Processing Record for Index 178: khatanga
# Processing Record for Index 179: saint anthony
# Processing Record for Index 180: marquette
# Processing Record for Index 181: karaul
# City not found... skipping.
# Processing Record for Index 182: port elizabeth
# Processing Record for Index 183: bababe
# City not found... skipping.
# Processing Record for Index 184: padang
# Processing Record for Index 185: umm bab
# Processing Record for Index 186: cairns
# Processing Record for Index 187: pinega
# Processing Record for Index 188: te anau
# Processing Record for Index 189: ouallam
# Processing Record for Index 190: penzance
# Processing Record for Index 191: talnakh
# Processing Record for Index 192: praia
# Processing Record for Index 193: broken hill
# Processing Record for Index 194: kedrovyy
# Processing Record for Index 195: suhbaatar
# Processing Record for Index 196: inuvik
# Processing Record for Index 197: saint-augustin
# Processing Record for Index 198: zheleznodorozhnyy
# Processing Record for Index 199: itapeva
# Processing Record for Index 200: guerrero negro
# Processing Record for Index 201: zhanakorgan
# Processing Record for Index 202: njombe
# Processing Record for Index 203: marica
# Processing Record for Index 204: longyearbyen
# Processing Record for Index 205: samoded
# Processing Record for Index 206: nueva helvecia
# Processing Record for Index 207: ratnagiri
# Processing Record for Index 208: gunjur
# Processing Record for Index 209: jega
# Processing Record for Index 210: kapaa
# Processing Record for Index 211: viedma
# Processing Record for Index 212: vilyuysk
# Processing Record for Index 213: biak
# Processing Record for Index 214: torbay
# Processing Record for Index 215: college
# Processing Record for Index 216: hasaki
# Processing Record for Index 217: skalistyy
# City not found... skipping.
# Processing Record for Index 218: omsukchan
# Processing Record for Index 219: kushikino
# Processing Record for Index 220: torgau
# Processing Record for Index 221: fortuna
# Processing Record for Index 222: batagay-alyta
# Processing Record for Index 223: taitung
# Processing Record for Index 224: hamilton
# Processing Record for Index 225: arlit
# Processing Record for Index 226: bairiki
# City not found... skipping.
# Processing Record for Index 227: ilebo
# Processing Record for Index 228: tongren
# Processing Record for Index 229: nanortalik
# Processing Record for Index 230: san miguel
# Processing Record for Index 231: mount isa
# Processing Record for Index 232: poum
# Processing Record for Index 233: rioja
# Processing Record for Index 234: hilo
# Processing Record for Index 235: kavieng
# Processing Record for Index 236: airai
# Processing Record for Index 237: nioro
# Processing Record for Index 238: saint george
# Processing Record for Index 239: karratha
# Processing Record for Index 240: novo aripuana
# Processing Record for Index 241: dubbo
# Processing Record for Index 242: port blair
# Processing Record for Index 243: bathsheba
# Processing Record for Index 244: kigoma
# Processing Record for Index 245: haines junction
# Processing Record for Index 246: port lincoln
# Processing Record for Index 247: aasiaat
# Processing Record for Index 248: santiago del estero
# Processing Record for Index 249: sungaipenuh
# Processing Record for Index 250: kruisfontein
# Processing Record for Index 251: buy
# Processing Record for Index 252: manyoni
# Processing Record for Index 253: derzhavinsk
# Processing Record for Index 254: mount gambier
# Processing Record for Index 255: marawi
# Processing Record for Index 256: goderich
# Processing Record for Index 257: itarema
# Processing Record for Index 258: sao joao da barra
# Processing Record for Index 259: sur
# Processing Record for Index 260: pagondas
# City not found... skipping.
# Processing Record for Index 261: natal
# Processing Record for Index 262: mogadishu
# Processing Record for Index 263: vao
# Processing Record for Index 264: mahajanga
# Processing Record for Index 265: saskatoon
# Processing Record for Index 266: namatanai
# Processing Record for Index 267: puerto ayora
# Processing Record for Index 268: gat
# Processing Record for Index 269: ambovombe
# Processing Record for Index 270: ponta do sol
# Processing Record for Index 271: ati
# Processing Record for Index 272: marystown
# Processing Record for Index 273: doctor mora
# Processing Record for Index 274: darlowo
# Processing Record for Index 275: portales
# Processing Record for Index 276: miyako
# Processing Record for Index 277: siderno
# Processing Record for Index 278: carman
# Processing Record for Index 279: lithgow
# Processing Record for Index 280: pimentel
# Processing Record for Index 281: havoysund
# Processing Record for Index 282: hamadan
# City not found... skipping.
# Processing Record for Index 283: wladyslawowo
# Processing Record for Index 284: meulaboh
# Processing Record for Index 285: buraydah
# Processing Record for Index 286: darhan
# Processing Record for Index 287: kuzovatovo
# Processing Record for Index 288: la romana
# Processing Record for Index 289: kirakira
# Processing Record for Index 290: thompson
# Processing Record for Index 291: egvekinot
# Processing Record for Index 292: talcahuano
# Processing Record for Index 293: yanan
# City not found... skipping.
# Processing Record for Index 294: coxcatlan
# Processing Record for Index 295: kavaratti
# Processing Record for Index 296: haapiti
# Processing Record for Index 297: coron
# Processing Record for Index 298: salalah
# Processing Record for Index 299: mossendjo
# Processing Record for Index 300: aspindza
# Processing Record for Index 301: zatoka
# Processing Record for Index 302: saravan
# Processing Record for Index 303: kikwit
# Processing Record for Index 304: pevek
# Processing Record for Index 305: praia da vitoria
# Processing Record for Index 306: stromness
# Processing Record for Index 307: achisay
# City not found... skipping.
# Processing Record for Index 308: naftah
# City not found... skipping.
# Processing Record for Index 309: bedesa
# Processing Record for Index 310: wagar
# Processing Record for Index 311: sola
# Processing Record for Index 312: isla vista
# Processing Record for Index 313: qasigiannguit
# Processing Record for Index 314: muros
# Processing Record for Index 315: utiel
# Processing Record for Index 316: longkou
# Processing Record for Index 317: ladario
# Processing Record for Index 318: sakassou
# Processing Record for Index 319: araouane
# Processing Record for Index 320: noumea
# Processing Record for Index 321: nemuro
# Processing Record for Index 322: bundibugyo
# Processing Record for Index 323: sorland
# Processing Record for Index 324: zhumadian
# Processing Record for Index 325: horasan
# Processing Record for Index 326: weligama
# Processing Record for Index 327: labytnangi
# Processing Record for Index 328: gornozavodsk
# Processing Record for Index 329: hay river
# Processing Record for Index 330: puerto ayacucho
# Processing Record for Index 331: kjollefjord
# Processing Record for Index 332: zhigansk
# Processing Record for Index 333: san patricio
# Processing Record for Index 334: taoudenni
# Processing Record for Index 335: terrace
# Processing Record for Index 336: morondava
# Processing Record for Index 337: puerto el triunfo
# Processing Record for Index 338: inverbervie
# Processing Record for Index 339: santa fe
# Processing Record for Index 340: mildura
# Processing Record for Index 341: luderitz
# Processing Record for Index 342: paranaiba
# Processing Record for Index 343: sedelnikovo
# City not found... skipping.
# Processing Record for Index 344: samusu
# City not found... skipping.
# Processing Record for Index 345: paciran
# Processing Record for Index 346: shimoda
# Processing Record for Index 347: kudat
# Processing Record for Index 348: mabaruma
# Processing Record for Index 349: tuggurt
# City not found... skipping.
# Processing Record for Index 350: vikulovo
# Processing Record for Index 351: lagoa
# Processing Record for Index 352: bhandaria
# Processing Record for Index 353: pavilosta
# Processing Record for Index 354: todos santos
# Processing Record for Index 355: flinders
# Processing Record for Index 356: dzhusaly
# City not found... skipping.
# Processing Record for Index 357: namibe
# Processing Record for Index 358: saint-joseph
# Processing Record for Index 359: paracuru
# Processing Record for Index 360: joshimath
# Processing Record for Index 361: dunedin
# Processing Record for Index 362: viseu
# Processing Record for Index 363: palabuhanratu
# City not found... skipping.
# Processing Record for Index 364: ribnitz-damgarten
# Processing Record for Index 365: ostrovnoy
# Processing Record for Index 366: lavrentiya
# Processing Record for Index 367: robertsport
# Processing Record for Index 368: nhulunbuy
# Processing Record for Index 369: kahului
# Processing Record for Index 370: tupik
# Processing Record for Index 371: marevo
# Processing Record for Index 372: luganville
# Processing Record for Index 373: warqla
# City not found... skipping.
# Processing Record for Index 374: whitehorse
# Processing Record for Index 375: ilulissat
# Processing Record for Index 376: malwan
# City not found... skipping.
# Processing Record for Index 377: parabel
# Processing Record for Index 378: rungata
# City not found... skipping.
# Processing Record for Index 379: alofi
# Processing Record for Index 380: qaqortoq
# Processing Record for Index 381: mpulungu
# Processing Record for Index 382: brooks
# Processing Record for Index 383: beasain
# Processing Record for Index 384: pombas
# Processing Record for Index 385: otjiwarongo
# Processing Record for Index 386: narsaq
# Processing Record for Index 387: vallenar
# Processing Record for Index 388: terney
# Processing Record for Index 389: san quintin
# Processing Record for Index 390: coihaique
# Processing Record for Index 391: margate
# Processing Record for Index 392: ibatiba
# Processing Record for Index 393: redlands
# Processing Record for Index 394: peace river
# Processing Record for Index 395: san andres
# Processing Record for Index 396: altay
# Processing Record for Index 397: shaunavon
# Processing Record for Index 398: kabalo
# Processing Record for Index 399: xunchang
# Processing Record for Index 400: severo-kurilsk
# Processing Record for Index 401: freeport
# Processing Record for Index 402: bargal
# City not found... skipping.
# Processing Record for Index 403: ust-kuyga
# Processing Record for Index 404: cabedelo
# Processing Record for Index 405: buala
# Processing Record for Index 406: mys shmidta
# City not found... skipping.
# Processing Record for Index 407: cayon
# Processing Record for Index 408: tekari
# Processing Record for Index 409: lower hutt
# Processing Record for Index 410: guiratinga
# Processing Record for Index 411: atbasar
# Processing Record for Index 412: acapulco
# Processing Record for Index 413: qandahar
# City not found... skipping.
# Processing Record for Index 414: grindavik
# Processing Record for Index 415: seoul
# Processing Record for Index 416: mangrol
# Processing Record for Index 417: colares
# Processing Record for Index 418: ketchikan
# Processing Record for Index 419: riyadh
# Processing Record for Index 420: marovoay
# Processing Record for Index 421: iquitos
# Processing Record for Index 422: olafsvik
# City not found... skipping.
# Processing Record for Index 423: teguldet
# Processing Record for Index 424: conde
# Processing Record for Index 425: copiapo
# Processing Record for Index 426: palana
# Processing Record for Index 427: theog
# Processing Record for Index 428: tigil
# Processing Record for Index 429: dolores
# Processing Record for Index 430: the valley
# Processing Record for Index 431: raudeberg
# Processing Record for Index 432: nalut
# Processing Record for Index 433: mizdah
# Processing Record for Index 434: sinjai
# Processing Record for Index 435: babanusah
# City not found... skipping.
# Processing Record for Index 436: mindelo
# Processing Record for Index 437: hobyo
# Processing Record for Index 438: sioux lookout
# Processing Record for Index 439: kargasok
# Processing Record for Index 440: najran
# Processing Record for Index 441: bonavista
# Processing Record for Index 442: caconda
# Processing Record for Index 443: adra
# Processing Record for Index 444: palpa
# Processing Record for Index 445: atambua
# Processing Record for Index 446: khandyga
# Processing Record for Index 447: yerbogachen
# Processing Record for Index 448: pisco
# Processing Record for Index 449: tautira
# Processing Record for Index 450: tumannyy
# City not found... skipping.
# Processing Record for Index 451: hirado
# Processing Record for Index 452: burriana
# Processing Record for Index 453: weihe
# Processing Record for Index 454: andenes
# City not found... skipping.
# Processing Record for Index 455: villazon
# City not found... skipping.
# Processing Record for Index 456: husavik
# Processing Record for Index 457: shache
# Processing Record for Index 458: floresta
# Processing Record for Index 459: limulunga
# Processing Record for Index 460: kasongo-lunda
# Processing Record for Index 461: avera
# Processing Record for Index 462: mar del plata
# Processing Record for Index 463: mae ramat
# Processing Record for Index 464: birsk
# Processing Record for Index 465: asau
# City not found... skipping.
# Processing Record for Index 466: vanimo
# Processing Record for Index 467: jacareacanga
# Processing Record for Index 468: kasane
# Processing Record for Index 469: sagua la grande
# Processing Record for Index 470: kununurra
# Processing Record for Index 471: vysha
# Processing Record for Index 472: rio gallegos
# Processing Record for Index 473: zanjan
# Processing Record for Index 474: krasnoselkup
# City not found... skipping.
# Processing Record for Index 475: nicolas bravo
# Processing Record for Index 476: patur
# Processing Record for Index 477: bay roberts
# Processing Record for Index 478: galgani
# City not found... skipping.
# Processing Record for Index 479: ruatoria
# City not found... skipping.
# Processing Record for Index 480: fort saint john
# City not found... skipping.
# Processing Record for Index 481: orsha
# Processing Record for Index 482: caravelas
# Processing Record for Index 483: zabaykalsk
# Processing Record for Index 484: wattegama
# Processing Record for Index 485: necochea
# Processing Record for Index 486: binabalian
# City not found... skipping.
# Processing Record for Index 487: batsfjord
# Processing Record for Index 488: creel
# Processing Record for Index 489: vardo
# Processing Record for Index 490: bosaso
# Processing Record for Index 491: altamont
# Processing Record for Index 492: attawapiskat
# City not found... skipping.
# Processing Record for Index 493: westport
# Processing Record for Index 494: hirara
# Processing Record for Index 495: camana
# City not found... skipping.
# Processing Record for Index 496: karpogory
# Processing Record for Index 497: shubarshi
# Processing Record for Index 498: pundaguitan
# Processing Record for Index 499: saint-pierre
# Processing Record for Index 500: comodoro rivadavia
# Processing Record for Index 501: solovetskiy
# City not found... skipping.
# Processing Record for Index 502: ulkan
# Processing Record for Index 503: pechora
# Processing Record for Index 504: impfondo
# Processing Record for Index 505: wewak
# Processing Record for Index 506: gangotri
# City not found... skipping.
# Processing Record for Index 507: mahaicony
# City not found... skipping.
# Processing Record for Index 508: prince george
# Processing Record for Index 509: uvalde
# Processing Record for Index 510: benghazi
# Processing Record for Index 511: port antonio
# Processing Record for Index 512: bengkulu
# City not found... skipping.
# Processing Record for Index 513: sinnamary
# Processing Record for Index 514: beringovskiy
# Processing Record for Index 515: sandane
# Processing Record for Index 516: vestmannaeyjar
# Processing Record for Index 517: nea kallikratia
# Processing Record for Index 518: nosy varika
# Processing Record for Index 519: dalby
# Processing Record for Index 520: dryden
# Processing Record for Index 521: tura
# Processing Record for Index 522: matamoros
# Processing Record for Index 523: bilibino
# Processing Record for Index 524: luwuk
# Processing Record for Index 525: hualmay
# Processing Record for Index 526: camanci
# City not found... skipping.
# Processing Record for Index 527: karamea
# City not found... skipping.
# Processing Record for Index 528: khonuu
# City not found... skipping.
# Processing Record for Index 529: pilis
# Processing Record for Index 530: venice
# Processing Record for Index 531: nova olimpia
# Processing Record for Index 532: trud
# Processing Record for Index 533: puerto leguizamo
# Processing Record for Index 534: acajutla
# Processing Record for Index 535: christchurch
# Processing Record for Index 536: tarbes
# Processing Record for Index 537: miraflores
# Processing Record for Index 538: umzimvubu
# City not found... skipping.
# Processing Record for Index 539: alice springs
# Processing Record for Index 540: guadix
# Processing Record for Index 541: havre-saint-pierre
# Processing Record for Index 542: gigmoto
# Processing Record for Index 543: chadiza
# Processing Record for Index 544: noyon
# Processing Record for Index 545: puerto escondido
# Processing Record for Index 546: rabo de peixe
# Processing Record for Index 547: boromo
# Processing Record for Index 548: novosheshminsk
# Processing Record for Index 549: xichang
# Processing Record for Index 550: esmeraldas
# Processing Record for Index 551: salisbury
# Processing Record for Index 552: lata
# Processing Record for Index 553: bambui
# Processing Record for Index 554: curup
# Processing Record for Index 555: diamantino
# Processing Record for Index 556: sobolevo
# Processing Record for Index 557: maumere
# Processing Record for Index 558: bindura
# Processing Record for Index 559: sitka
# Processing Record for Index 560: kirsanov
# Processing Record for Index 561: port hedland
# Processing Record for Index 562: mae chan
# Processing Record for Index 563: sovetskiy
# Processing Record for Index 564: dulce nombre de culmi
# Processing Record for Index 565: abu zabad
# Processing Record for Index 566: gura teghii
# Processing Record for Index 567: chester
# Processing Record for Index 568: gondanglegi
# Processing Record for Index 569: lasa
# Processing Record for Index 570: varna
# Processing Record for Index 571: henties bay
# Processing Record for Index 572: ulladulla
# Processing Record for Index 573: ler
# Processing Record for Index 574: bulgan
# Processing Record for Index 575: gazanjyk
# Processing Record for Index 576: hailin
# Processing Record for Index 577: matara
# Processing Record for Index 578: burns lake
# Processing Record for Index 579: broome
# Processing Record for Index 580: bolungarvik
# City not found... skipping.
# Processing Record for Index 581: leh
# Processing Record for Index 582: ambon
# Processing Record for Index 583: rolim de moura
# City not found... skipping.
# Processing Record for Index 584: kozachi laheri
# Processing Record for Index 585: kamaishi
# Processing Record for Index 586: shipunovo
# Processing Record for Index 587: ryotsu
# Processing Record for Index 588: pitimbu
# Processing Record for Index 589: algiers
# Processing Record for Index 590: roald
# Processing Record for Index 591: tarpon springs
# Processing Record for Index 592: maningrida
# Processing Record for Index 593: nsanje
# Processing Record for Index 594: masuguru
# Processing Record for Index 595: wilmington
# Processing Record for Index 596: felanitx
# Processing Record for Index 597: ylojarvi
# Processing Record for Index 598: manggar
# ---------------------
# Data Retrieval Complete.
# ---------------------

# %%
# checking the dataframe now
df.head()
# Out:
#           City Cloudiness Country        Date Humidity    Lat     Lng  \
# 0  baie-comeau          1      CA  1561405709       20  49.22  -68.15
# 1        tokur        100      RU  1561405709       98  53.13   132.9
# 2      sechura         58      PE  1561405709       92  -5.56  -80.82
# 3    hithadhoo          1      MV  1561405636       73   -0.6   73.08
# 4      rikitea         67      PF  1561405710       86 -23.12 -134.97
#
#   Max Temp Wind Speed
# 0     73.4      12.75
# 1    42.35      10.29
# 2    63.77      17.29
# 3    83.57       5.12
# 4    71.33      13.58

# %%
# replacing null values with Nan
df = df.replace('', np.NaN)
df.head()
df.to_csv(r'weather_data.csv')

# %%
# storing today's date for titles
today = date.today().strftime('%m/%d/%y')

# %%
# using pandas plot wrapper to plot each plot
df.plot(kind = "scatter", x = ("Lat"), y = "Max Temp", c = "steelblue", edgecolors = "Black", s = 60, figsize = (12,8), grid = True, linewidths = 1.2, fontsize = 12)
plt.title(f"City Latitude vs. Max Temperature ({today})", fontsize = 20)
plt.ylabel("Max Temperature (F)", fontsize = 16)
plt.xlabel("Latitude", fontsize = 16)
plt.savefig('Max_Temp.png')

# %%
# sometimes record with report humidities well above 100 and this would significantly affect the scaling of my plot 
# so here I am removing data with that error

humid_df = df[df.Humidity <= 100]
humid_df.plot(kind = "scatter", x = ("Lat"), y = "Humidity", c = "steelblue", edgecolors = "Black", s = 60, figsize = (12,8), grid = True, linewidths = 1.2, fontsize = 12)
plt.title(f"City Latitude vs. Humidity ({today})", fontsize = 20)
plt.ylabel("Humidity (%)", fontsize = 16)
plt.xlabel("Latitude", fontsize = 16)
plt.savefig('Humidity.png')

# %%
df.plot(kind = "scatter", x = ("Lat"), y = "Cloudiness", c = "steelblue", edgecolors = "Black", s = 60, figsize = (12,8), grid = True, linewidths = 1.2, fontsize = 12)
plt.title(f"City Latitude vs. Cloudiness ({today})", fontsize = 20)
plt.ylabel("Cloudiness (%)", fontsize = 16)
plt.xlabel("Latitude", fontsize = 16)
plt.savefig('Cloudiness.png')

# %%
df.plot(kind = "scatter", x = ("Lat"), y = "Wind Speed", c = "steelblue", edgecolors = "Black", s = 60, figsize = (12,8), grid = True, linewidths = 1.2, fontsize = 12)
plt.title(f"City Latitude vs. Wind Speed ({today})", fontsize = 20)
plt.ylabel("Wind Speed (mph)", fontsize = 16)
plt.xlabel("Latitude", fontsize = 16)
plt.savefig('Wind_Speed.png')
