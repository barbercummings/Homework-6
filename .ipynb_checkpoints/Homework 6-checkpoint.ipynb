# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %%
df = pd.DataFrame(cities)
df = df.rename(columns = {0: "City"})

# %%
df['Cloudiness'] = ""
df['Country'] = ""
df['Date'] = ""
df['Humidity'] = ""
df['Lat'] = ""
df['Lng'] = ""
df['Max Temp'] = ""
df['Wind Speed'] = ""
df.head()
# Out:
#              City Cloudiness Country Date Humidity Lat Lng Max Temp Wind Speed
# 0        zalesovo
# 1       miranorte
# 2  severo-kurilsk
# 3      butaritari
# 4         ushuaia

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# %%
query_url = f"{url}appid={api_key}&units={units}&q="
query_url_test = f"{url}appid={api_key}&units={units}"

# %%
response = requests.get(query_url +"London").json()
response
# Out:
# {'coord': {'lon': -0.13, 'lat': 51.51},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 16.32,
#   'pressure': 1021,
#   'humidity': 63,
#   'temp_min': 13.89,
#   'temp_max': 19},
#  'visibility': 10000,
#  'wind': {'speed': 3.1, 'deg': 220},
#  'clouds': {'all': 75},
#  'dt': 1561149338,
#  'sys': {'type': 1,
#   'id': 1414,
#   'message': 0.0086,
#   'country': 'GB',
#   'sunrise': 1561088581,
#   'sunset': 1561148482},
#  'timezone': 3600,
#  'id': 2643743,
#  'name': 'London',
#  'cod': 200}

# %%
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
print("Beginning Data Retrieval \n ---------------------")

for index, row in df.iterrows():
    
    city_name = row["City"]

    # assemble url and make API request
    print(f"Processing Record for Index {index}: {city_name}")
    response = requests.get(query_url + city_name).json()
    
    try: 
        df.loc[index, 'Cloudiness'] = response['clouds']['all']
        df.loc[index, 'Country'] = response['sys']['country']
        df.loc[index, 'Date'] = response['dt']
        df.loc[index, 'Humidity'] = response['main']['humidity']
        df.loc[index, 'Lat'] = response['coord']['lat']
        df.loc[index, 'Lng'] = response['coord']['lon']
        df.loc[index, 'Max Temp'] = response['main']['temp_max']
        df.loc[index, 'Wind Speed'] = response['wind']['speed']
        
    except (KeyError, IndexError):
        print("City not found... skipping.")
              
              
print("--------------------- \nData Retrival Complete. \n---------------------")
# Out:
# Beginning Data Retrieval
#  ---------------------
# Processeing Record for Index 0: zalesovo
# Processeing Record for Index 1: miranorte
# City not found... skipping.
# Processeing Record for Index 2: severo-kurilsk
# Processeing Record for Index 3: butaritari
# Processeing Record for Index 4: ushuaia
# Processeing Record for Index 5: busselton
# Processeing Record for Index 6: roma
# Processeing Record for Index 7: saskylakh
# Processeing Record for Index 8: tuktoyaktuk
# Processeing Record for Index 9: mandalgovi
# Processeing Record for Index 10: cape town
# Processeing Record for Index 11: hilo
# Processeing Record for Index 12: nikolskoye
# Processeing Record for Index 13: chokurdakh
# Processeing Record for Index 14: bethel
# Processeing Record for Index 15: kavieng
# Processeing Record for Index 16: vestmannaeyjar
# Processeing Record for Index 17: humaita
# Processeing Record for Index 18: nago
# Processeing Record for Index 19: matara
# Processeing Record for Index 20: cabo san lucas
# Processeing Record for Index 21: illoqqortoormiut
# City not found... skipping.
# Processeing Record for Index 22: lasa
# Processeing Record for Index 23: matadi
# Processeing Record for Index 24: ossora
# Processeing Record for Index 25: mataura
# Processeing Record for Index 26: sukhobezvodnoye
# Processeing Record for Index 27: georgetown
# Processeing Record for Index 28: torbat-e jam
# Processeing Record for Index 29: pisco
# Processeing Record for Index 30: buraydah
# Processeing Record for Index 31: castro
# Processeing Record for Index 32: talnakh
# Processeing Record for Index 33: urumqi
# City not found... skipping.
# Processeing Record for Index 34: atuona
# Processeing Record for Index 35: hambantota
# Processeing Record for Index 36: rikitea
# Processeing Record for Index 37: albany
# Processeing Record for Index 38: taolanaro
# City not found... skipping.
# Processeing Record for Index 39: vaini
# Processeing Record for Index 40: khatanga
# Processeing Record for Index 41: ajdabiya
# Processeing Record for Index 42: thompson
# Processeing Record for Index 43: dikson
# Processeing Record for Index 44: hervey bay
# Processeing Record for Index 45: sioux lookout
# Processeing Record for Index 46: beringovskiy
# Processeing Record for Index 47: japura
# Processeing Record for Index 48: hermanus
# Processeing Record for Index 49: sola
# Processeing Record for Index 50: tura
# Processeing Record for Index 51: kawana waters
# City not found... skipping.
# Processeing Record for Index 52: ruatoria
# City not found... skipping.
# Processeing Record for Index 53: viedma
# Processeing Record for Index 54: hobart
# Processeing Record for Index 55: pevek
# Processeing Record for Index 56: lokosovo
# Processeing Record for Index 57: kapaa
# Processeing Record for Index 58: punta arenas
# Processeing Record for Index 59: qaanaaq
# Processeing Record for Index 60: barrow
# Processeing Record for Index 61: jamestown
# Processeing Record for Index 62: torbay
# Processeing Record for Index 63: bluff
# Processeing Record for Index 64: hofn
# Processeing Record for Index 65: avarua
# Processeing Record for Index 66: spasskoye
# Processeing Record for Index 67: ulladulla
# Processeing Record for Index 68: sterling
# Processeing Record for Index 69: louisbourg
# City not found... skipping.
# Processeing Record for Index 70: leningradskiy
# Processeing Record for Index 71: arraial do cabo
# Processeing Record for Index 72: kaitangata
# Processeing Record for Index 73: ribeira grande
# Processeing Record for Index 74: balikpapan
# Processeing Record for Index 75: amderma
# City not found... skipping.
# Processeing Record for Index 76: anshun
# Processeing Record for Index 77: fukue
# Processeing Record for Index 78: port alfred
# Processeing Record for Index 79: chegdomyn
# Processeing Record for Index 80: wulanhaote
# City not found... skipping.
# Processeing Record for Index 81: mys shmidta
# City not found... skipping.
# Processeing Record for Index 82: mount gambier
# Processeing Record for Index 83: solosolo
# Processeing Record for Index 84: haibowan
# City not found... skipping.
# Processeing Record for Index 85: bilma
# Processeing Record for Index 86: codrington
# Processeing Record for Index 87: hualmay
# Processeing Record for Index 88: faanui
# Processeing Record for Index 89: ampanihy
# Processeing Record for Index 90: east london
# Processeing Record for Index 91: bredasdorp
# Processeing Record for Index 92: bengkulu
# City not found... skipping.
# Processeing Record for Index 93: lebu
# Processeing Record for Index 94: port hardy
# Processeing Record for Index 95: sistranda
# Processeing Record for Index 96: puerto ayora
# Processeing Record for Index 97: willowmore
# Processeing Record for Index 98: katsuura
# Processeing Record for Index 99: sur
# Processeing Record for Index 100: mar del plata
# Processeing Record for Index 101: along
# Processeing Record for Index 102: huarmey
# Processeing Record for Index 103: provideniya
# Processeing Record for Index 104: kloulklubed
# Processeing Record for Index 105: scottsburgh
# City not found... skipping.
# Processeing Record for Index 106: cicanesti
# City not found... skipping.
# Processeing Record for Index 107: bereda
# Processeing Record for Index 108: samusu
# City not found... skipping.
# Processeing Record for Index 109: upernavik
# Processeing Record for Index 110: kodiak
# Processeing Record for Index 111: zhanaozen
# Processeing Record for Index 112: new norfolk
# Processeing Record for Index 113: marcona
# City not found... skipping.
# Processeing Record for Index 114: mount isa
# Processeing Record for Index 115: rocha
# Processeing Record for Index 116: yellowknife
# Processeing Record for Index 117: mormugao
# City not found... skipping.
# Processeing Record for Index 118: nordlingen
# City not found... skipping.
# Processeing Record for Index 119: port elizabeth
# Processeing Record for Index 120: atar
# Processeing Record for Index 121: deputatskiy
# Processeing Record for Index 122: sao gabriel da cachoeira
# Processeing Record for Index 123: la ronge
# Processeing Record for Index 124: storm lake
# Processeing Record for Index 125: ilulissat
# Processeing Record for Index 126: dingle
# Processeing Record for Index 127: ambikapur
# Processeing Record for Index 128: cherskiy
# Processeing Record for Index 129: westport
# Processeing Record for Index 130: maniitsoq
# Processeing Record for Index 131: pirovskoye
# Processeing Record for Index 132: najran
# Processeing Record for Index 133: zhigansk
# Processeing Record for Index 134: ondjiva
# Processeing Record for Index 135: naze
# Processeing Record for Index 136: cochrane
# Processeing Record for Index 137: baoding
# Processeing Record for Index 138: guerrero negro
# Processeing Record for Index 139: lompoc
# Processeing Record for Index 140: luderitz
# Processeing Record for Index 141: inuvik
# Processeing Record for Index 142: northam
# Processeing Record for Index 143: shingu
# Processeing Record for Index 144: bakchar
# Processeing Record for Index 145: ponta do sol
# Processeing Record for Index 146: timmins
# Processeing Record for Index 147: vardo
# Processeing Record for Index 148: locri
# Processeing Record for Index 149: chake chake
# Processeing Record for Index 150: alofi
# Processeing Record for Index 151: sakakah
# City not found... skipping.
# Processeing Record for Index 152: kraslava
# Processeing Record for Index 153: okhotsk
# Processeing Record for Index 154: peterhead
# Processeing Record for Index 155: horasan
# Processeing Record for Index 156: saint-philippe
# Processeing Record for Index 157: yanan
# City not found... skipping.
# Processeing Record for Index 158: kendari
# Processeing Record for Index 159: kalaleh
# Processeing Record for Index 160: souillac
# Processeing Record for Index 161: vao
# Processeing Record for Index 162: werda
# Processeing Record for Index 163: aquiraz
# Processeing Record for Index 164: saint anthony
# Processeing Record for Index 165: idah
# Processeing Record for Index 166: clyde river
# Processeing Record for Index 167: san nicolas
# Processeing Record for Index 168: geraldton
# Processeing Record for Index 169: utiroa
# City not found... skipping.
# Processeing Record for Index 170: attawapiskat
# City not found... skipping.
# Processeing Record for Index 171: iralaya
# Processeing Record for Index 172: tumannyy
# City not found... skipping.
# Processeing Record for Index 173: lerwick
# Processeing Record for Index 174: meybod
# Processeing Record for Index 175: awjilah
# Processeing Record for Index 176: touros
# Processeing Record for Index 177: arlit
# Processeing Record for Index 178: qui nhon
# City not found... skipping.
# Processeing Record for Index 179: tocopilla
# Processeing Record for Index 180: waddan
# Processeing Record for Index 181: ryotsu
# Processeing Record for Index 182: solovetskiy
# City not found... skipping.
# Processeing Record for Index 183: nobres
# Processeing Record for Index 184: toliary
# City not found... skipping.
# Processeing Record for Index 185: barra
# Processeing Record for Index 186: acapulco
# Processeing Record for Index 187: tasiilaq
# Processeing Record for Index 188: pacific grove
# Processeing Record for Index 189: stornoway
# City not found... skipping.
# Processeing Record for Index 190: paracuru
# Processeing Record for Index 191: yalta
# Processeing Record for Index 192: barentsburg
# City not found... skipping.
# Processeing Record for Index 193: chiali
# City not found... skipping.
# Processeing Record for Index 194: hithadhoo
# Processeing Record for Index 195: hailar
# Processeing Record for Index 196: kuruksay
# City not found... skipping.
# Processeing Record for Index 197: matagami
# Processeing Record for Index 198: saint george
# Processeing Record for Index 199: sibolga
# Processeing Record for Index 200: evensk
# Processeing Record for Index 201: alto longa
# Processeing Record for Index 202: pahrump
# Processeing Record for Index 203: tchibanga
# Processeing Record for Index 204: keti bandar
# Processeing Record for Index 205: payakumbuh
# Processeing Record for Index 206: sitka
# Processeing Record for Index 207: vaitupu
# City not found... skipping.
# Processeing Record for Index 208: kenai
# Processeing Record for Index 209: cabedelo
# Processeing Record for Index 210: rock sound
# Processeing Record for Index 211: tiksi
# Processeing Record for Index 212: jinchang
# Processeing Record for Index 213: fertod
# Processeing Record for Index 214: vila velha
# Processeing Record for Index 215: san quintin
# Processeing Record for Index 216: tilichiki
# Processeing Record for Index 217: wewak
# Processeing Record for Index 218: tual
# Processeing Record for Index 219: frederikshavn
# Processeing Record for Index 220: catuday
# Processeing Record for Index 221: esperance
# Processeing Record for Index 222: port-gentil
# Processeing Record for Index 223: saint-augustin
# Processeing Record for Index 224: dakar
# Processeing Record for Index 225: morant bay
# Processeing Record for Index 226: lagoa
# Processeing Record for Index 227: gbadolite
# Processeing Record for Index 228: kununurra
# Processeing Record for Index 229: yialos
# City not found... skipping.
# Processeing Record for Index 230: roald
# Processeing Record for Index 231: kargasok
# Processeing Record for Index 232: hovd
# Processeing Record for Index 233: phan thiet
# Processeing Record for Index 234: pangnirtung
# Processeing Record for Index 235: soe
# Processeing Record for Index 236: kijang
# Processeing Record for Index 237: college
# Processeing Record for Index 238: ostrovnoy
# Processeing Record for Index 239: marsa matruh
# Processeing Record for Index 240: slavsk
# Processeing Record for Index 241: eyl
# Processeing Record for Index 242: qiongshan
# Processeing Record for Index 243: nanortalik
# Processeing Record for Index 244: hun
# Processeing Record for Index 245: jacareacanga
# Processeing Record for Index 246: yulara
# Processeing Record for Index 247: moussoro
# Processeing Record for Index 248: grajau
# City not found... skipping.
# Processeing Record for Index 249: torit
# City not found... skipping.
# Processeing Record for Index 250: mundi
# Processeing Record for Index 251: mahebourg
# Processeing Record for Index 252: amroha
# Processeing Record for Index 253: gamba
# Processeing Record for Index 254: yako
# Processeing Record for Index 255: lorengau
# Processeing Record for Index 256: flin flon
# Processeing Record for Index 257: jinxiang
# Processeing Record for Index 258: teya
# Processeing Record for Index 259: itaquyry
# Processeing Record for Index 260: esfarayen
# Processeing Record for Index 261: great yarmouth
# Processeing Record for Index 262: husavik
# Processeing Record for Index 263: beni suef
# Processeing Record for Index 264: malanje
# Processeing Record for Index 265: te anau
# Processeing Record for Index 266: cam ranh
# Processeing Record for Index 267: pangoa
# Processeing Record for Index 268: ambilobe
# Processeing Record for Index 269: burkburnett
# Processeing Record for Index 270: maputo
# Processeing Record for Index 271: imbituba
# Processeing Record for Index 272: caninde
# City not found... skipping.
# Processeing Record for Index 273: lubao
# Processeing Record for Index 274: seoul
# Processeing Record for Index 275: hunza
# City not found... skipping.
# Processeing Record for Index 276: maneadero
# City not found... skipping.
# Processeing Record for Index 277: karratha
# Processeing Record for Index 278: san patricio
# Processeing Record for Index 279: kyshtovka
# Processeing Record for Index 280: chuy
# Processeing Record for Index 281: ahipara
# Processeing Record for Index 282: lumphat
# Processeing Record for Index 283: koslan
# Processeing Record for Index 284: cairns
# Processeing Record for Index 285: saldanha
# Processeing Record for Index 286: alta floresta
# Processeing Record for Index 287: makokou
# Processeing Record for Index 288: sona
# Processeing Record for Index 289: norman wells
# Processeing Record for Index 290: rudbar
# City not found... skipping.
# Processeing Record for Index 291: odweyne
# City not found... skipping.
# Processeing Record for Index 292: carnarvon
# Processeing Record for Index 293: toamasina
# Processeing Record for Index 294: yenagoa
# Processeing Record for Index 295: sao mateus
# Processeing Record for Index 296: severnyy
# City not found... skipping.
# Processeing Record for Index 297: ituni
# City not found... skipping.
# Processeing Record for Index 298: bermejo
# Processeing Record for Index 299: inhambane
# Processeing Record for Index 300: malindi
# Processeing Record for Index 301: hobyo
# Processeing Record for Index 302: rawannawi
# City not found... skipping.
# Processeing Record for Index 303: makakilo city
# Processeing Record for Index 304: avera
# Processeing Record for Index 305: trairi
# Processeing Record for Index 306: lazaro cardenas
# Processeing Record for Index 307: iqaluit
# Processeing Record for Index 308: kuching
# Processeing Record for Index 309: emirdag
# Processeing Record for Index 310: saleaula
# City not found... skipping.
# Processeing Record for Index 311: atambua
# Processeing Record for Index 312: simao
# Processeing Record for Index 313: bilibino
# Processeing Record for Index 314: tirumullaivasal
# Processeing Record for Index 315: fortuna
# Processeing Record for Index 316: belushya guba
# City not found... skipping.
# Processeing Record for Index 317: havoysund
# Processeing Record for Index 318: marawi
# Processeing Record for Index 319: santa rosa
# Processeing Record for Index 320: ndele
# City not found... skipping.
# Processeing Record for Index 321: kuche
# City not found... skipping.
# Processeing Record for Index 322: chipinge
# Processeing Record for Index 323: terenos
# Processeing Record for Index 324: taseyevo
# Processeing Record for Index 325: poronaysk
# Processeing Record for Index 326: mugur-aksy
# Processeing Record for Index 327: maragogi
# Processeing Record for Index 328: sept-iles
# Processeing Record for Index 329: stabat
# Processeing Record for Index 330: duz
# City not found... skipping.
# Processeing Record for Index 331: ancud
# Processeing Record for Index 332: sisimiut
# Processeing Record for Index 333: santa marta
# Processeing Record for Index 334: qunduz
# City not found... skipping.
# Processeing Record for Index 335: egvekinot
# Processeing Record for Index 336: pundaguitan
# Processeing Record for Index 337: longyearbyen
# Processeing Record for Index 338: narsaq
# Processeing Record for Index 339: wanning
# Processeing Record for Index 340: santa fe
# Processeing Record for Index 341: peniche
# Processeing Record for Index 342: los llanos de aridane
# Processeing Record for Index 343: tazovskiy
# Processeing Record for Index 344: arrecife
# City not found... skipping.
# Processeing Record for Index 345: muros
# Processeing Record for Index 346: morondava
# Processeing Record for Index 347: babanusah
# City not found... skipping.
# Processeing Record for Index 348: airai
# Processeing Record for Index 349: haines junction
# Processeing Record for Index 350: vanavara
# Processeing Record for Index 351: salsk
# Processeing Record for Index 352: abu dhabi
# Processeing Record for Index 353: portland
# Processeing Record for Index 354: resistencia
# Processeing Record for Index 355: vanimo
# Processeing Record for Index 356: kushiro
# Processeing Record for Index 357: corner brook
# Processeing Record for Index 358: erdaojiang
# Processeing Record for Index 359: kangaatsiaq
# Processeing Record for Index 360: sorland
# Processeing Record for Index 361: victoria
# Processeing Record for Index 362: lamu
# Processeing Record for Index 363: paita
# Processeing Record for Index 364: waipawa
# Processeing Record for Index 365: padang
# Processeing Record for Index 366: bela
# Processeing Record for Index 367: hopatcong
# Processeing Record for Index 368: channel-port aux basques
# Processeing Record for Index 369: baldone
# Processeing Record for Index 370: bay-khaak
# Processeing Record for Index 371: griffith
# Processeing Record for Index 372: aykhal
# Processeing Record for Index 373: satitoa
# City not found... skipping.
# Processeing Record for Index 374: snezhnogorsk
# Processeing Record for Index 375: teguldet
# Processeing Record for Index 376: qaqortoq
# Processeing Record for Index 377: hanyang
# Processeing Record for Index 378: san cristobal
# Processeing Record for Index 379: port augusta
# Processeing Record for Index 380: ordzhonikidze
# Processeing Record for Index 381: uryupinsk
# Processeing Record for Index 382: ahumada
# City not found... skipping.
# Processeing Record for Index 383: mehamn
# Processeing Record for Index 384: tiznit
# Processeing Record for Index 385: thunder bay
# Processeing Record for Index 386: caravelas
# Processeing Record for Index 387: zhuhai
# Processeing Record for Index 388: uglegorsk
# Processeing Record for Index 389: ambodifototra
# City not found... skipping.
# Processeing Record for Index 390: comodoro rivadavia
# Processeing Record for Index 391: tuatapere
# Processeing Record for Index 392: road town
# Processeing Record for Index 393: klaksvik
# Processeing Record for Index 394: necochea
# Processeing Record for Index 395: yirol
# City not found... skipping.
# Processeing Record for Index 396: pinheiro machado
# Processeing Record for Index 397: laguna
# Processeing Record for Index 398: nouadhibou
# Processeing Record for Index 399: rio gallegos
# Processeing Record for Index 400: nara
# Processeing Record for Index 401: saint-joseph
# Processeing Record for Index 402: bambous virieux
# Processeing Record for Index 403: richards bay
# Processeing Record for Index 404: itarema
# Processeing Record for Index 405: sambava
# Processeing Record for Index 406: matamoros
# Processeing Record for Index 407: leshukonskoye
# Processeing Record for Index 408: juegang
# Processeing Record for Index 409: tsihombe
# City not found... skipping.
# Processeing Record for Index 410: marfino
# Processeing Record for Index 411: lavrentiya
# Processeing Record for Index 412: shimoda
# Processeing Record for Index 413: loreto
# Processeing Record for Index 414: makarov
# Processeing Record for Index 415: jibuti
# City not found... skipping.
# Processeing Record for Index 416: sentyabrskiy
# City not found... skipping.
# Processeing Record for Index 417: the pas
# Processeing Record for Index 418: krasnoobsk
# Processeing Record for Index 419: tecpan
# Processeing Record for Index 420: bandarbeyla
# Processeing Record for Index 421: kamenskoye
# City not found... skipping.
# Processeing Record for Index 422: digha
# Processeing Record for Index 423: savonlinna
# Processeing Record for Index 424: takoradi
# Processeing Record for Index 425: barra do garcas
# Processeing Record for Index 426: kudahuvadhoo
# Processeing Record for Index 427: ilhabela
# Processeing Record for Index 428: waldoboro
# Processeing Record for Index 429: olafsvik
# City not found... skipping.
# Processeing Record for Index 430: placido de castro
# Processeing Record for Index 431: hegang
# Processeing Record for Index 432: temaraia
# City not found... skipping.
# Processeing Record for Index 433: mindelo
# Processeing Record for Index 434: nizhneyansk
# City not found... skipping.
# Processeing Record for Index 435: sonari
# Processeing Record for Index 436: iroquois falls
# Processeing Record for Index 437: aklavik
# Processeing Record for Index 438: samalaeulu
# City not found... skipping.
# Processeing Record for Index 439: pimenteiras
# Processeing Record for Index 440: saint-louis
# Processeing Record for Index 441: novopskov
# Processeing Record for Index 442: verkhoyansk
# Processeing Record for Index 443: kahului
# Processeing Record for Index 444: sorong
# Processeing Record for Index 445: grand centre
# City not found... skipping.
# Processeing Record for Index 446: baherden
# Processeing Record for Index 447: palmerston
# Processeing Record for Index 448: gao
# Processeing Record for Index 449: kudat
# Processeing Record for Index 450: bumba
# Processeing Record for Index 451: walvis bay
# Processeing Record for Index 452: ridgecrest
# Processeing Record for Index 453: mitu
# Processeing Record for Index 454: corn island
# Processeing Record for Index 455: tabas
# Processeing Record for Index 456: kamaishi
# Processeing Record for Index 457: huazolotitlan
# City not found... skipping.
# Processeing Record for Index 458: luganville
# Processeing Record for Index 459: khromtau
# Processeing Record for Index 460: sala
# Processeing Record for Index 461: oussouye
# Processeing Record for Index 462: mocambique
# City not found... skipping.
# Processeing Record for Index 463: nizhneangarsk
# Processeing Record for Index 464: auki
# Processeing Record for Index 465: abrau-dyurso
# Processeing Record for Index 466: kati
# Processeing Record for Index 467: kilakarai
# City not found... skipping.
# Processeing Record for Index 468: isangel
# Processeing Record for Index 469: gornyye klyuchi
# Processeing Record for Index 470: xining
# Processeing Record for Index 471: aras
# Processeing Record for Index 472: cedar city
# Processeing Record for Index 473: tarudant
# City not found... skipping.
# Processeing Record for Index 474: tabou
# Processeing Record for Index 475: srednekolymsk
# Processeing Record for Index 476: galveston
# Processeing Record for Index 477: bestobe
# Processeing Record for Index 478: ravar
# Processeing Record for Index 479: balabac
# Processeing Record for Index 480: brae
# Processeing Record for Index 481: kruisfontein
# Processeing Record for Index 482: bairiki
# City not found... skipping.
# Processeing Record for Index 483: ngama
# City not found... skipping.
# Processeing Record for Index 484: polson
# Processeing Record for Index 485: duku
# Processeing Record for Index 486: vigrestad
# Processeing Record for Index 487: senneterre
# Processeing Record for Index 488: beatrice
# Processeing Record for Index 489: gushikawa
# Processeing Record for Index 490: ukiah
# Processeing Record for Index 491: alghero
# Processeing Record for Index 492: alyangula
# Processeing Record for Index 493: olovyannaya
# Processeing Record for Index 494: seddon
# Processeing Record for Index 495: itoman
# Processeing Record for Index 496: ayotzintepec
# Processeing Record for Index 497: porto novo
# Processeing Record for Index 498: elizabeth city
# Processeing Record for Index 499: malinyi
# Processeing Record for Index 500: presidencia roque saenz pena
# Processeing Record for Index 501: arroyo
# Processeing Record for Index 502: eureka
# Processeing Record for Index 503: quepos
# Processeing Record for Index 504: grand river south east
# City not found... skipping.
# Processeing Record for Index 505: nemuro
# Processeing Record for Index 506: alenquer
# Processeing Record for Index 507: salalah
# Processeing Record for Index 508: lodja
# Processeing Record for Index 509: deder
# Processeing Record for Index 510: san policarpo
# Processeing Record for Index 511: khasan
# Processeing Record for Index 512: meyungs
# City not found... skipping.
# Processeing Record for Index 513: yumen
# Processeing Record for Index 514: taiobeiras
# Processeing Record for Index 515: breisach
# City not found... skipping.
# Processeing Record for Index 516: yanai
# Processeing Record for Index 517: garden city
# Processeing Record for Index 518: roebourne
# Processeing Record for Index 519: ibipora
# Processeing Record for Index 520: celestun
# Processeing Record for Index 521: jumla
# Processeing Record for Index 522: coihaique
# Processeing Record for Index 523: bafra
# City not found... skipping.
# Processeing Record for Index 524: shakawe
# Processeing Record for Index 525: muzhi
# Processeing Record for Index 526: sobolevo
# Processeing Record for Index 527: henties bay
# Processeing Record for Index 528: tamiahua
# Processeing Record for Index 529: salekhard
# Processeing Record for Index 530: falealupo
# City not found... skipping.
# Processeing Record for Index 531: wala
# Processeing Record for Index 532: fairbanks
# Processeing Record for Index 533: panaba
# Processeing Record for Index 534: riyadh
# Processeing Record for Index 535: cayenne
# Processeing Record for Index 536: lengshuitan
# Processeing Record for Index 537: altamira
# Processeing Record for Index 538: batagay-alyta
# Processeing Record for Index 539: paramonga
# Processeing Record for Index 540: cidreira
# Processeing Record for Index 541: dali
# Processeing Record for Index 542: morros
# Processeing Record for Index 543: birjand
# Processeing Record for Index 544: madina
# Processeing Record for Index 545: fare
# Processeing Record for Index 546: kattivakkam
# Processeing Record for Index 547: karauzyak
# City not found... skipping.
# Processeing Record for Index 548: killybegs
# Processeing Record for Index 549: tawang
# Processeing Record for Index 550: bosarkany
# Processeing Record for Index 551: krasnoarmeysk
# Processeing Record for Index 552: erenhot
# Processeing Record for Index 553: burnie
# Processeing Record for Index 554: camacha
# Processeing Record for Index 555: gorno-chuyskiy
# City not found... skipping.
# Processeing Record for Index 556: dudinka
# Processeing Record for Index 557: iwanai
# Processeing Record for Index 558: kilmez
# City not found... skipping.
# Processeing Record for Index 559: paltinis
# Processeing Record for Index 560: mitsamiouli
# Processeing Record for Index 561: palmer
# Processeing Record for Index 562: illintsi
# Processeing Record for Index 563: lakselv
# Processeing Record for Index 564: jand
# Processeing Record for Index 565: ketchikan
# Processeing Record for Index 566: half moon bay
# Processeing Record for Index 567: adre
# Processeing Record for Index 568: puqi
# Processeing Record for Index 569: kurchum
# Processeing Record for Index 570: nelson bay
# Processeing Record for Index 571: andrelandia
# City not found... skipping.
# Processeing Record for Index 572: youkounkoun
# Processeing Record for Index 573: mocajuba
# Processeing Record for Index 574: kharp
# Processeing Record for Index 575: jablah
# Processeing Record for Index 576: erzin
# Processeing Record for Index 577: sembabule
# Processeing Record for Index 578: trelaze
# Processeing Record for Index 579: muli
# Processeing Record for Index 580: bontang
# Processeing Record for Index 581: tessalit
# Processeing Record for Index 582: booue
# Processeing Record for Index 583: shubarkuduk
# Processeing Record for Index 584: kristianstad
# Processeing Record for Index 585: salamiyah
# Processeing Record for Index 586: le vauclin
# Processeing Record for Index 587: chernyshevskiy
# Processeing Record for Index 588: troitsko-pechorsk
# Processeing Record for Index 589: chagda
# City not found... skipping.
# Processeing Record for Index 590: zamora
# Processeing Record for Index 591: honiara
# Processeing Record for Index 592: anar darreh
# City not found... skipping.
# Processeing Record for Index 593: nurota
# Processeing Record for Index 594: cobija
# Processeing Record for Index 595: halvad
# Processeing Record for Index 596: marrakesh
# Processeing Record for Index 597: denia
# Processeing Record for Index 598: ikorodu
# Processeing Record for Index 599: marzuq
# Processeing Record for Index 600: ulaangom
# Processeing Record for Index 601: ushtobe
# Processeing Record for Index 602: constitucion
# Processeing Record for Index 603: litoral del san juan
# City not found... skipping.
# Processeing Record for Index 604: abha
# Processeing Record for Index 605: rassvet
# Processeing Record for Index 606: ponta delgada
# Processeing Record for Index 607: storslett
# Processeing Record for Index 608: myrtle beach
# Processeing Record for Index 609: bojnurd
# Processeing Record for Index 610: nizhnyaya poyma
# Processeing Record for Index 611: abbeville
# Processeing Record for Index 612: dunedin
# ---------------------
# Data Retrival Complete.
# ---------------------

# %%
df
# Out:
#                      City Cloudiness Country        Date Humidity    Lat  \
# 0                zalesovo         71      RU  1561150165       87     54
# 1               miranorte
# 2          severo-kurilsk        100      RU  1561150165       96  50.68
# 3              butaritari         82      KI  1561149800       78   3.07
# 4                 ushuaia         90      AR  1561149793       93 -54.81
# 5               busselton         52      AU  1561149829       79 -33.64
# 6                    roma          0      IT  1561150037       57  41.89
# 7               saskylakh         58      RU  1561150166       58  71.97
# 8             tuktoyaktuk         75      CA  1561149804       55  69.44
# 9              mandalgovi        100      MN  1561150167       24  45.76
# 10              cape town         90      ZA  1561149601       82 -33.93
# 11                   hilo         75      US  1561149798       65  19.71
# 12             nikolskoye         75      RU  1561150167       94   59.7
# 13             chokurdakh          0      RU  1561149799       48  70.62
# 14                 bethel         75      US  1561149803       67  60.79
# 15                kavieng        100      PG  1561149799       78  -2.57
# 16         vestmannaeyjar         34      IS  1561150168       74  63.44
# 17                humaita          0      AR  1561150169       27 -24.93
# 18                   nago          0      IT  1561150169       47  45.88
# 19                 matara         20      PE  1561150169       50 -13.74
# 20         cabo san lucas          5      MX  1561149962       18  22.89
# 21       illoqqortoormiut
# 22                   lasa         20      CY  1561150170       88  34.92
# 23                 matadi          0      CD  1561150170       87  -5.83
# 24                 ossora        100      RU  1561150171       83  59.24
# 25                mataura        100      NZ  1561149792       95 -46.19
# 26        sukhobezvodnoye         74      RU  1561150171       81  57.05
# 27             georgetown         40      GY  1561149615       83    6.8
# 28           torbat-e jam          0      IR  1561150172       17  35.24
# 29                  pisco         75      PE  1561150172       30 -13.71
# ..                    ...        ...     ...         ...      ...    ...
# 583           shubarkuduk         45      KZ  1561150361       58  49.15
# 584          kristianstad          0      SE  1561150361       93  56.03
# 585             salamiyah          0      SY  1561150362       77  35.01
# 586            le vauclin         75      MQ  1561150362       70  14.55
# 587        chernyshevskiy          0      RU  1561150362       61  63.01
# 588     troitsko-pechorsk          3      RU  1561150363       72  62.71
# 589                chagda
# 590                zamora          1      ES  1561150363       48  41.51
# 591               honiara         20      SB  1561150363       94  -9.43
# 592           anar darreh
# 593                nurota          0      UZ  1561150364       25  40.56
# 594                cobija         40      BR  1561150364       62 -11.02
# 595                halvad          6      IN  1561150364       69  23.02
# 596             marrakesh          0      MA  1561150365       44  31.63
# 597                 denia         52      ES  1561150365       88  38.84
# 598               ikorodu         95      NG  1561150365       85   6.62
# 599                marzuq         58      YE  1561150366       38   14.4
# 600              ulaangom         78      MN  1561150366       45  49.98
# 601               ushtobe         35      KZ  1561150366       28  45.25
# 602          constitucion         75      MX  1561150367       17  23.99
# 603  litoral del san juan
# 604                  abha          5      SA  1561150367       16  18.22
# 605               rassvet          0      MD  1561150367       88   47.2
# 606         ponta delgada         40      PT  1561150106       93  37.73
# 607             storslett        100      NO  1561150368       87  69.77
# 608          myrtle beach          1      US  1561150368       40   33.7
# 609               bojnurd         40      IR  1561150369       47  37.47
# 610       nizhnyaya poyma          0      RU  1561150369       64  56.16
# 611             abbeville          0      FR  1561150369       82  50.11
# 612               dunedin        100      NZ  1561150142       69 -45.87
#
#         Lng Max Temp Wind Speed
# 0     84.74    12.85       1.01
# 1
# 2    156.12     6.65       3.77
# 3    172.79    28.55       5.37
# 4    -68.31        2        1.5
# 5    115.35       15        8.8
# 6     12.48    24.44        1.5
# 7    114.09    11.15       6.64
# 8   -133.03       19        7.2
# 9    106.27    20.95       3.86
# 10    18.42    16.11        9.3
# 11  -155.08    29.44        1.5
# 12    30.79    21.67       3.33
# 13    147.9    12.95        6.7
# 14  -161.76       16        3.1
# 15    150.8    28.05       2.68
# 16   -20.27    11.05       7.74
# 17   -65.37       24        2.6
# 18    10.89       27        2.6
# 19    -72.9       14       3.89
# 20  -109.91    38.33        6.2
# 21
# 22    32.53       24        2.1
# 23    13.46    20.95       0.93
# 24   163.07     7.65       1.91
# 25   168.86     5.56       1.57
# 26    44.89    17.25       1.84
# 27   -58.16       29        4.1
# 28    60.63    22.95       0.75
# 29    -76.2       22        3.1
# ..      ...      ...        ...
# 583   56.49    21.55       4.74
# 584   14.16       14        2.1
# 585   37.05    21.05        4.7
# 586  -60.84       30        7.2
# 587  112.47    12.95       1.12
# 588   56.19     5.55       1.92
# 589
# 590   -5.74       20        3.1
# 591  159.96       24        2.1
# 592
# 593   65.69       24          1
# 594  -68.77       30        1.5
# 595   71.18    29.65       6.52
# 596   -7.99       25        6.7
# 597    0.11    22.22        2.3
# 598     3.5    26.35        6.4
# 599   46.47    27.85       1.12
# 600   92.07    15.85       1.73
# 601   77.98    22.35       2.98
# 602 -104.67       29        4.1
# 603
# 604    42.5       26        3.6
# 605   28.43    23.89        2.1
# 606  -25.67       19        6.7
# 607   21.03    10.25          2
# 608  -78.89    33.89        2.6
# 609   57.33       26        4.1
# 610    97.2    12.35       1.66
# 611    1.83       15        2.1
# 612   170.5     7.22       1.34
#
# [613 rows x 9 columns]
